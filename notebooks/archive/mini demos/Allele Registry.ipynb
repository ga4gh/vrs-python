# %%
import copy
from vmc.extra.bundlemanager import BundleManager
from vmc.extra.alleleregistry import AlleleRegistryClient

# %%
arc = AlleleRegistryClient(
    base_url="http://reg.test.genome.network",
    login="testuser",
    password="testuser"
    )

# %%
d = arc.get_allele(hgvs="NC_000010.11:g.87894077C>T")

# %%
# Out:
# {'@context': 'http://reg.test.genome.network/schema/allele.jsonld',
#  '@id': 'http://reg.test.genome.network/allele/CA000318',
#  'externalRecords': {'COSMIC': [{'@id': 'http://cancer.sanger.ac.uk/cosmic/mutation/overview?id=5168',
#     'active': True,
#     'id': 'COSM5168'}],
#   'ClinVarAlleles': [{'@id': 'http://www.ncbi.nlm.nih.gov/clinvar/?term=98720[alleleid]',
#     'alleleId': 98720,
#     'preferredName': 'NM_000314.6(PTEN):c.132C>T (p.Gly44=)'}],
#   'ClinVarVariations': [{'@id': 'http://www.ncbi.nlm.nih.gov/clinvar/variation/92813',
#     'RCV': ['RCV000078606', 'RCV000123045', 'RCV000162387', 'RCV000512721'],
#     'variationId': 92813}],
#   'ExAC': [{'@id': 'http://exac.broadinstitute.org/variant/10-89653834-C-T',
#     'id': '10-89653834-C-T',
#     'variant': '10:89653834 C / T'}],
#   'MyVariantInfo_hg19': [{'@id': 'http://myvariant.info/v1/variant/chr10:g.89653834C>T?assembly=hg19',
#     'id': 'chr10:g.89653834C>T'}],
#   'MyVariantInfo_hg38': [{'@id': 'http://myvariant.info/v1/variant/chr10:g.87894077C>T?assembly=hg38',
#     'id': 'chr10:g.87894077C>T'}],
#   'dbSNP': [{'@id': 'http://www.ncbi.nlm.nih.gov/snp/150651961',
#     'rs': 150651961}],
#   'gnomAD': [{'@id': 'http://gnomad.broadinstitute.org/variant/10-89653834-C-T',
#     'id': '10-89653834-C-T',
#     'variant': '10:89653834 C / T'}]},
#  'genomicAlleles': [{'chromosome': '10',
#    'coordinates': [{'allele': 'T',
#      'end': 87894077,
#      'referenceAllele': 'C',
#      'start': 87894076}],
#    'hgvs': ['NC_000010.11:g.87894077C>T', 'CM000672.2:g.87894077C>T'],
#    'referenceGenome': 'GRCh38',
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS000058'},
#   {'chromosome': '10',
#    'coordinates': [{'allele': 'T',
#      'end': 89643814,
#      'referenceAllele': 'C',
#      'start': 89643813}],
#    'hgvs': ['NC_000010.9:g.89643814C>T'],
#    'referenceGenome': 'NCBI36',
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS000010'},
#   {'chromosome': '10',
#    'coordinates': [{'allele': 'T',
#      'end': 89653834,
#      'referenceAllele': 'C',
#      'start': 89653833}],
#    'hgvs': ['NC_000010.10:g.89653834C>T', 'CM000672.1:g.89653834C>T'],
#    'referenceGenome': 'GRCh37',
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS000034'},
#   {'coordinates': [{'allele': 'T',
#      'end': 35639,
#      'referenceAllele': 'C',
#      'start': 35638}],
#    'hgvs': ['NG_007466.2:g.35639C>T', 'LRG_311:g.35639C>T'],
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS000591'}],
#  'transcriptAlleles': [{'coordinates': [{'allele': 'T',
#      'end': 1163,
#      'referenceAllele': 'C',
#      'start': 1162}],
#    'gene': 'http://reg.test.genome.network/gene/GN009588',
#    'geneNCBI_id': 5728,
#    'geneSymbol': 'PTEN',
#    'hgvs': ['NM_000314.5:c.132C>T'],
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS006376'},
#   {'coordinates': [{'allele': 'T',
#      'end': 1163,
#      'referenceAllele': 'C',
#      'start': 1162}],
#    'gene': 'http://reg.test.genome.network/gene/GN009588',
#    'geneNCBI_id': 5728,
#    'geneSymbol': 'PTEN',
#    'hgvs': ['NM_000314.6:c.132C>T'],
#    'proteinEffect': {'hgvs': 'NP_000305.3:p.Gly44='},
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS006377'},
#   {'coordinates': [{'allele': 'T',
#      'end': 1163,
#      'referenceAllele': 'C',
#      'start': 1162}],
#    'gene': 'http://reg.test.genome.network/gene/GN009588',
#    'geneNCBI_id': 5728,
#    'geneSymbol': 'PTEN',
#    'hgvs': ['NM_001304717.2:c.651C>T'],
#    'proteinEffect': {'hgvs': 'NP_001291646.2:p.Gly217='},
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS025775'},
#   {'coordinates': [{'allele': 'T',
#      'end': 1163,
#      'referenceAllele': 'C',
#      'start': 1162}],
#    'gene': 'http://reg.test.genome.network/gene/GN009588',
#    'geneNCBI_id': 5728,
#    'geneSymbol': 'PTEN',
#    'hgvs': ['NM_001304718.1:c.-574C>T'],
#    'proteinEffect': {'hgvs': 'NP_001291647.1:p.='},
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS025776'},
#   {'coordinates': [{'allele': 'T',
#      'end': 844,
#      'referenceAllele': 'C',
#      'start': 843}],
#    'gene': 'http://reg.test.genome.network/gene/GN009588',
#    'geneNCBI_id': 5728,
#    'geneSymbol': 'PTEN',
#    'hgvs': ['XM_006717926.2:c.132C>T'],
#    'proteinEffect': {'hgvs': 'XP_006717989.1:p.Gly44='},
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS072385'},
#   {'coordinates': [{'allele': 'T',
#      'end': 844,
#      'referenceAllele': 'C',
#      'start': 843}],
#    'gene': 'http://reg.test.genome.network/gene/GN009588',
#    'geneNCBI_id': 5728,
#    'geneSymbol': 'PTEN',
#    'hgvs': ['XM_011539981.1:c.132C>T'],
#    'proteinEffect': {'hgvs': 'XP_011538283.1:p.Gly44='},
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS106931'},
#   {'coordinates': [{'allele': 'T',
#      'end': 3848,
#      'endIntronDirection': '+',
#      'endIntronOffset': 13639,
#      'referenceAllele': 'C',
#      'start': 3848,
#      'startIntronDirection': '+',
#      'startIntronOffset': 13638}],
#    'gene': 'http://reg.test.genome.network/gene/GN009588',
#    'geneNCBI_id': 5728,
#    'geneSymbol': 'PTEN',
#    'hgvs': ['XM_011539982.1:c.68+13639C>T'],
#    'proteinEffect': {'hgvs': 'XP_011538284.1:p.='},
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS106932'},
#   {'coordinates': [{'allele': 'T',
#      'end': 844,
#      'referenceAllele': 'C',
#      'start': 843}],
#    'gene': 'http://reg.test.genome.network/gene/GN009588',
#    'geneNCBI_id': 5728,
#    'geneSymbol': 'PTEN',
#    'hgvs': ['XR_945789.1:n.844C>T'],
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS139422'},
#   {'coordinates': [{'allele': 'T',
#      'end': 844,
#      'referenceAllele': 'C',
#      'start': 843}],
#    'gene': 'http://reg.test.genome.network/gene/GN009588',
#    'geneNCBI_id': 5728,
#    'geneSymbol': 'PTEN',
#    'hgvs': ['XR_945790.1:n.844C>T'],
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS139423'},
#   {'coordinates': [{'allele': 'T',
#      'end': 844,
#      'referenceAllele': 'C',
#      'start': 843}],
#    'gene': 'http://reg.test.genome.network/gene/GN009588',
#    'geneNCBI_id': 5728,
#    'geneSymbol': 'PTEN',
#    'hgvs': ['XR_945791.1:n.844C>T'],
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS139424'},
#   {'coordinates': [{'allele': 'T',
#      'end': 1489,
#      'referenceAllele': 'C',
#      'start': 1488}],
#    'hgvs': ['ENST00000371953.7:c.132C>T'],
#    'proteinEffect': {'hgvs': 'ENSP00000361021.3:p.Gly44='},
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS247170'},
#   {'coordinates': [{'allele': 'T',
#      'end': 134,
#      'referenceAllele': 'C',
#      'start': 133}],
#    'hgvs': ['ENST00000462694.1:n.134C>T'],
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS306889'},
#   {'coordinates': [{'allele': 'T',
#      'end': 1164,
#      'referenceAllele': 'C',
#      'start': 1163}],
#    'hgvs': ['ENST00000610634.1:c.30C>T'],
#    'proteinEffect': {'hgvs': 'ENSP00000477517.1:p.Gly10='},
#    'referenceSequence': 'http://reg.test.genome.network/refseq/RS400508'}],
#  'type': 'nucleotide'}
