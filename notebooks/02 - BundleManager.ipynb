# %% [markdown]
# # Creating ApoE Bundles from HGVS
#
# HGVS is the de facto standard for manipulating human-readable variation data. This notebook demonstrates the VMC BundleManager, which facilitates translating HGVS expressions to Alleles, Haplotypes, and Genotypes.
#
#
# ```
#                              rs7412
#                              NC_000019.10:g.44908822
#                              NM_000041.3:c.526
#                              C          T
# rs429358                 C   APOE-ε4    APOE-ε1
# NC_000019.10:g.44908684  T   APOE-ε3    APOE-ε2
# NM_000041.3:c.388
# ```

# %%
apoe_alleles = {
    'rs7412C': {'g37': 'NC_000019.9:g.45412079=',
                'g38': 'NC_000019.10:g.44908822=',
                'c': 'NM_000041.3:c.526=',
                'p': 'NP_000032.1:p.Arg176='},
    'rs7412T': {'g37': 'NC_000019.9:g.45412079C>T',
                'g38': 'NC_000019.10:g.44908822C>T',
                'c': 'NM_000041.3:c.526C>T',
                'p': 'NP_000032.1:p.Arg176Cys'},
    'rs429358T': {'g37': 'NC_000019.9:g.45411941=',
                  'g38': 'NC_000019.10:g.44908684=',
                  'c': 'NM_000041.3:c.388=',
                  'p': 'NP_000032.1:p.Cys130='},
    'rs429358C': {'g37': 'NC_000019.9:g.45411941T>C',
                  'g38': 'NC_000019.10:g.44908684T>C',
                  'c': 'NM_000041.3:c.388T>C',
                  'p': 'NP_000032.1:p.Cys130Arg'}
}
apoe_haplotypes = {
    "ε1": ["rs429358C", "rs7412T"],
    "ε2": ["rs429358T", "rs7412T"],
    "ε3": ["rs429358T", "rs7412C"],
    "ε4": ["rs429358C", "rs7412C"],
}

# %%
from vmc.extra.bundlemanager import BundleManager
bm = BundleManager()

# %% [markdown]
# # Alleles

# %%
for vname, alleles in apoe_alleles.items():
    for h in alleles.values():
        a = bm.add_hgvs_allele(h)

# %% [markdown]
# # Haplotypes

# %%
haplotypes_hgvs = {
    t: {name: [apoe_alleles[vname][t] for vname in vnames] for name, vnames in apoe_haplotypes.items()}
    for t in "g37 g38 c p".split()
}
haplotypes_hgvs
# Out:
# {'g37': {'ε1': ['NC_000019.9:g.45411941T>C', 'NC_000019.9:g.45412079C>T'],
#   'ε2': ['NC_000019.9:g.45411941=', 'NC_000019.9:g.45412079C>T'],
#   'ε3': ['NC_000019.9:g.45411941=', 'NC_000019.9:g.45412079='],
#   'ε4': ['NC_000019.9:g.45411941T>C', 'NC_000019.9:g.45412079=']},
#  'g38': {'ε1': ['NC_000019.10:g.44908684T>C', 'NC_000019.10:g.44908822C>T'],
#   'ε2': ['NC_000019.10:g.44908684=', 'NC_000019.10:g.44908822C>T'],
#   'ε3': ['NC_000019.10:g.44908684=', 'NC_000019.10:g.44908822='],
#   'ε4': ['NC_000019.10:g.44908684T>C', 'NC_000019.10:g.44908822=']},
#  'c': {'ε1': ['NM_000041.3:c.388T>C', 'NM_000041.3:c.526C>T'],
#   'ε2': ['NM_000041.3:c.388=', 'NM_000041.3:c.526C>T'],
#   'ε3': ['NM_000041.3:c.388=', 'NM_000041.3:c.526='],
#   'ε4': ['NM_000041.3:c.388T>C', 'NM_000041.3:c.526=']},
#  'p': {'ε1': ['NP_000032.1:p.Cys130Arg', 'NP_000032.1:p.Arg176Cys'],
#   'ε2': ['NP_000032.1:p.Cys130=', 'NP_000032.1:p.Arg176Cys'],
#   'ε3': ['NP_000032.1:p.Cys130=', 'NP_000032.1:p.Arg176='],
#   'ε4': ['NP_000032.1:p.Cys130Arg', 'NP_000032.1:p.Arg176=']}}

# %%
# create protein haplotypes
for t in "g37 g38 c p".split():
    for name, hs in haplotypes_hgvs[t].items():
        h = bm.add_hgvs_haplotype(hs)

# %%
for t in "g37 g38 c p".split():
    hht = haplotypes_hgvs[t]
    for h1 in "ε3 ε4".split():
        for h2 in "ε3 ε4".split():
            gt_alleles = (hht[h1], hht[h2])
            g = bm.add_hgvs_genotype(gt_alleles)

# %%
bm.as_bundle().as_dict()
# Out:
# {'alleles': {'VMC:GA_eMSY7YTp8vF94KLHb--gTFIw7ZTCL-g9': {'id': 'VMC:GA_eMSY7YTp8vF94KLHb--gTFIw7ZTCL-g9',
#    'location_id': 'VMC:GL_pP3VNZk9XnBbKCpbmWZ_4uo7glzy52B8',
#    'state': 'C'},
#   'VMC:GA__8rLiy7YkQDNy-t536RpVFGxIDiWLr6J': {'id': 'VMC:GA__8rLiy7YkQDNy-t536RpVFGxIDiWLr6J',
#    'location_id': 'VMC:GL_heG_PQopyF0Vgi4zH6yiLf3diyfyJcV3',
#    'state': 'C'},
#   'VMC:GA_FF1sjhCulonKevwWyUtHz0elzKkMGOia': {'id': 'VMC:GA_FF1sjhCulonKevwWyUtHz0elzKkMGOia',
#    'location_id': 'VMC:GL_YxX7xmdBNfU4PsUR-SGVbx2UpFplLOfO',
#    'state': 'G'},
#   'VMC:GA_HXfVz-_qMdKeEuF8-jw6JYrjR2aFWC9d': {'id': 'VMC:GA_HXfVz-_qMdKeEuF8-jw6JYrjR2aFWC9d',
#    'location_id': 'VMC:GL_dTK1c6jdZmkSUqVYQBESKi8-G3U1SvAR',
#    'state': 'R'},
#   'VMC:GA_juxtrStjpvLUPWoHIeJ7rEhpYCMe37vJ': {'id': 'VMC:GA_juxtrStjpvLUPWoHIeJ7rEhpYCMe37vJ',
#    'location_id': 'VMC:GL_pP3VNZk9XnBbKCpbmWZ_4uo7glzy52B8',
#    'state': 'T'},
#   'VMC:GA_BqFKgQ350SUi4-uaGCvMM1ag7z0dNmvC': {'id': 'VMC:GA_BqFKgQ350SUi4-uaGCvMM1ag7z0dNmvC',
#    'location_id': 'VMC:GL_heG_PQopyF0Vgi4zH6yiLf3diyfyJcV3',
#    'state': 'T'},
#   'VMC:GA_8GXRvwUiPqedmbLe8XC5bjU0MAtGzVaf': {'id': 'VMC:GA_8GXRvwUiPqedmbLe8XC5bjU0MAtGzVaf',
#    'location_id': 'VMC:GL_YxX7xmdBNfU4PsUR-SGVbx2UpFplLOfO',
#    'state': 'T'},
#   'VMC:GA_nDecjk95OUW67OEl8gF5GSdFhMTbCQLR': {'id': 'VMC:GA_nDecjk95OUW67OEl8gF5GSdFhMTbCQLR',
#    'location_id': 'VMC:GL_dTK1c6jdZmkSUqVYQBESKi8-G3U1SvAR',
#    'state': 'C'},
#   'VMC:GA_c3riRG4RXZkCCk7VAjEC--vgttPDB_uy': {'id': 'VMC:GA_c3riRG4RXZkCCk7VAjEC--vgttPDB_uy',
#    'location_id': 'VMC:GL_vCYRMzR95jmQ1VYwpUfthSZ8TVQMFwLB',
#    'state': 'T'},
#   'VMC:GA_AnJl99FJB5tNPupduz8I4R8CCuwCpIY0': {'id': 'VMC:GA_AnJl99FJB5tNPupduz8I4R8CCuwCpIY0',
#    'location_id': 'VMC:GL_L1IS6jOwSUsOpKihGRcqxHul1IwbV-1s',
#    'state': 'T'},
#   'VMC:GA_FDez5GA0kZdSJ--h3stLv9LF8l4OQ-_I': {'id': 'VMC:GA_FDez5GA0kZdSJ--h3stLv9LF8l4OQ-_I',
#    'location_id': 'VMC:GL_8-ViSIvP5iAmlIt4bXVLOLrA_Nf_emgJ',
#    'state': 'C'},
#   'VMC:GA_5PpUoSppTEXHTXguTPcQLj7dQrlyuU06': {'id': 'VMC:GA_5PpUoSppTEXHTXguTPcQLj7dQrlyuU06',
#    'location_id': 'VMC:GL_TyoxavrWtcusjpiKFmWxVCXSAu98-G6a',
#    'state': 'C'},
#   'VMC:GA_ifRiguPmxS6uzuqqLCYUggk8xFHE_jHm': {'id': 'VMC:GA_ifRiguPmxS6uzuqqLCYUggk8xFHE_jHm',
#    'location_id': 'VMC:GL_vCYRMzR95jmQ1VYwpUfthSZ8TVQMFwLB',
#    'state': 'C'},
#   'VMC:GA_zsJuMckKGajqHCl16sxKQJtBMjGrFHHZ': {'id': 'VMC:GA_zsJuMckKGajqHCl16sxKQJtBMjGrFHHZ',
#    'location_id': 'VMC:GL_L1IS6jOwSUsOpKihGRcqxHul1IwbV-1s',
#    'state': 'C'},
#   'VMC:GA_O67oha84SsAJeSHMHr7aY2R57et-UZUS': {'id': 'VMC:GA_O67oha84SsAJeSHMHr7aY2R57et-UZUS',
#    'location_id': 'VMC:GL_TyoxavrWtcusjpiKFmWxVCXSAu98-G6a',
#    'state': 'R'}},
#  'genotypes': {'VMC:GG_7grmnUynCARDv4RSgNhPGJzZXhPk8MOL': {'completeness': 'UNKNOWN',
#    'haplotype_ids': ['VMC:GH_XglDW0H9gct4KNp1qAu2vUH2KsyHl5Qn',
#     'VMC:GH_XglDW0H9gct4KNp1qAu2vUH2KsyHl5Qn'],
#    'id': 'VMC:GG_7grmnUynCARDv4RSgNhPGJzZXhPk8MOL'},
#   'VMC:GG_ZQO34nZRLOS0FzRQe6Gu6hCwo_m8VJ2F': {'completeness': 'UNKNOWN',
#    'haplotype_ids': ['VMC:GH_I-ovRRgzOBuBArd6QayoKrKunL5RGGeA',
#     'VMC:GH_XglDW0H9gct4KNp1qAu2vUH2KsyHl5Qn'],
#    'id': 'VMC:GG_ZQO34nZRLOS0FzRQe6Gu6hCwo_m8VJ2F'},
#   'VMC:GG_-6u926QMiLTr1EPceIFPEbDKLU-js59K': {'completeness': 'UNKNOWN',
#    'haplotype_ids': ['VMC:GH_I-ovRRgzOBuBArd6QayoKrKunL5RGGeA',
#     'VMC:GH_I-ovRRgzOBuBArd6QayoKrKunL5RGGeA'],
#    'id': 'VMC:GG_-6u926QMiLTr1EPceIFPEbDKLU-js59K'},
#   'VMC:GG__qHLsPHI-JzjC8isSsTQEah1mLwQaxYo': {'completeness': 'UNKNOWN',
#    'haplotype_ids': ['VMC:GH_kUQO4V_hncXqY8Wom5-AONMPenAQtFDf',
#     'VMC:GH_kUQO4V_hncXqY8Wom5-AONMPenAQtFDf'],
#    'id': 'VMC:GG__qHLsPHI-JzjC8isSsTQEah1mLwQaxYo'},
#   'VMC:GG_-wht2rBIhuZm7w9CP68O0urG7ttMljVG': {'completeness': 'UNKNOWN',
#    'haplotype_ids': ['VMC:GH_mjW4ESgyl28tJF25c5nL0Zt97CWD-dp1',
#     'VMC:GH_kUQO4V_hncXqY8Wom5-AONMPenAQtFDf'],
#    'id': 'VMC:GG_-wht2rBIhuZm7w9CP68O0urG7ttMljVG'},
#   'VMC:GG_tUyN1o5EZO0ytfIn2BKJWcrmUqzlAMZb': {'completeness': 'UNKNOWN',
#    'haplotype_ids': ['VMC:GH_mjW4ESgyl28tJF25c5nL0Zt97CWD-dp1',
#     'VMC:GH_mjW4ESgyl28tJF25c5nL0Zt97CWD-dp1'],
#    'id': 'VMC:GG_tUyN1o5EZO0ytfIn2BKJWcrmUqzlAMZb'},
#   'VMC:GG_W7iU9_MMK4rYy4sz_SPH8Wb30Apzhvxd': {'completeness': 'UNKNOWN',
#    'haplotype_ids': ['VMC:GH_URkWr6JSsokL-Gby8Fkq2rtrK3nNAouP',
#     'VMC:GH_URkWr6JSsokL-Gby8Fkq2rtrK3nNAouP'],
#    'id': 'VMC:GG_W7iU9_MMK4rYy4sz_SPH8Wb30Apzhvxd'},
#   'VMC:GG_Hv-zJml6HWx7y8EXTPD8IqFgTVq93utD': {'completeness': 'UNKNOWN',
#    'haplotype_ids': ['VMC:GH_H4GaT_yDDvJT1SkK5NtsEVfBHJspIncO',
#     'VMC:GH_H4GaT_yDDvJT1SkK5NtsEVfBHJspIncO'],
#    'id': 'VMC:GG_Hv-zJml6HWx7y8EXTPD8IqFgTVq93utD'},
#   'VMC:GG_CKp0YB8pyuzkRh7ZwQ_Mh2peD4zjjrPh': {'completeness': 'UNKNOWN',
#    'haplotype_ids': ['VMC:GH_K3iMP1SeScExjniYSpN6-42gowOPwgcu',
#     'VMC:GH_H4GaT_yDDvJT1SkK5NtsEVfBHJspIncO'],
#    'id': 'VMC:GG_CKp0YB8pyuzkRh7ZwQ_Mh2peD4zjjrPh'},
#   'VMC:GG_8bgNMQaf-1SXollyvI0uTfromBhGUlqI': {'completeness': 'UNKNOWN',
#    'haplotype_ids': ['VMC:GH_K3iMP1SeScExjniYSpN6-42gowOPwgcu',
#     'VMC:GH_K3iMP1SeScExjniYSpN6-42gowOPwgcu'],
#    'id': 'VMC:GG_8bgNMQaf-1SXollyvI0uTfromBhGUlqI'}},
#  'haplotypes': {'VMC:GH_i9GaMzv-IoIrxQ0CbhzoQoDQJKRuBjiP': {'allele_ids': ['VMC:GA_ifRiguPmxS6uzuqqLCYUggk8xFHE_jHm',
#     'VMC:GA_juxtrStjpvLUPWoHIeJ7rEhpYCMe37vJ'],
#    'completeness': 'UNKNOWN',
#    'id': 'VMC:GH_i9GaMzv-IoIrxQ0CbhzoQoDQJKRuBjiP',
#    'location_id': 'VMC:GL_2VyJB7nPtJwowLsnt4g9glSXXI2dmHS6'},
#   'VMC:GH_tVHomQQxifayfJeuyj86VT-yI3YeX2WU': {'allele_ids': ['VMC:GA_c3riRG4RXZkCCk7VAjEC--vgttPDB_uy',
#     'VMC:GA_juxtrStjpvLUPWoHIeJ7rEhpYCMe37vJ'],
#    'completeness': 'UNKNOWN',
#    'id': 'VMC:GH_tVHomQQxifayfJeuyj86VT-yI3YeX2WU',
#    'location_id': 'VMC:GL_2VyJB7nPtJwowLsnt4g9glSXXI2dmHS6'},
#   'VMC:GH_XglDW0H9gct4KNp1qAu2vUH2KsyHl5Qn': {'allele_ids': ['VMC:GA_c3riRG4RXZkCCk7VAjEC--vgttPDB_uy',
#     'VMC:GA_eMSY7YTp8vF94KLHb--gTFIw7ZTCL-g9'],
#    'completeness': 'UNKNOWN',
#    'id': 'VMC:GH_XglDW0H9gct4KNp1qAu2vUH2KsyHl5Qn',
#    'location_id': 'VMC:GL_2VyJB7nPtJwowLsnt4g9glSXXI2dmHS6'},
#   'VMC:GH_I-ovRRgzOBuBArd6QayoKrKunL5RGGeA': {'allele_ids': ['VMC:GA_ifRiguPmxS6uzuqqLCYUggk8xFHE_jHm',
#     'VMC:GA_eMSY7YTp8vF94KLHb--gTFIw7ZTCL-g9'],
#    'completeness': 'UNKNOWN',
#    'id': 'VMC:GH_I-ovRRgzOBuBArd6QayoKrKunL5RGGeA',
#    'location_id': 'VMC:GL_2VyJB7nPtJwowLsnt4g9glSXXI2dmHS6'},
#   'VMC:GH_xcoQV-5dYfklzV2MBeM-3iXKsnbUqok4': {'allele_ids': ['VMC:GA_zsJuMckKGajqHCl16sxKQJtBMjGrFHHZ',
#     'VMC:GA_BqFKgQ350SUi4-uaGCvMM1ag7z0dNmvC'],
#    'completeness': 'UNKNOWN',
#    'id': 'VMC:GH_xcoQV-5dYfklzV2MBeM-3iXKsnbUqok4',
#    'location_id': 'VMC:GL_8Vq74MSEdcvgKy4XwQWoA8nQAtW-lWV0'},
#   'VMC:GH_1Et2ByaI4XG2hObDqfREGgbuzTexBSEH': {'allele_ids': ['VMC:GA_AnJl99FJB5tNPupduz8I4R8CCuwCpIY0',
#     'VMC:GA_BqFKgQ350SUi4-uaGCvMM1ag7z0dNmvC'],
#    'completeness': 'UNKNOWN',
#    'id': 'VMC:GH_1Et2ByaI4XG2hObDqfREGgbuzTexBSEH',
#    'location_id': 'VMC:GL_8Vq74MSEdcvgKy4XwQWoA8nQAtW-lWV0'},
#   'VMC:GH_kUQO4V_hncXqY8Wom5-AONMPenAQtFDf': {'allele_ids': ['VMC:GA_AnJl99FJB5tNPupduz8I4R8CCuwCpIY0',
#     'VMC:GA__8rLiy7YkQDNy-t536RpVFGxIDiWLr6J'],
#    'completeness': 'UNKNOWN',
#    'id': 'VMC:GH_kUQO4V_hncXqY8Wom5-AONMPenAQtFDf',
#    'location_id': 'VMC:GL_8Vq74MSEdcvgKy4XwQWoA8nQAtW-lWV0'},
#   'VMC:GH_mjW4ESgyl28tJF25c5nL0Zt97CWD-dp1': {'allele_ids': ['VMC:GA_zsJuMckKGajqHCl16sxKQJtBMjGrFHHZ',
#     'VMC:GA__8rLiy7YkQDNy-t536RpVFGxIDiWLr6J'],
#    'completeness': 'UNKNOWN',
#    'id': 'VMC:GH_mjW4ESgyl28tJF25c5nL0Zt97CWD-dp1',
#    'location_id': 'VMC:GL_8Vq74MSEdcvgKy4XwQWoA8nQAtW-lWV0'},
#   'VMC:GH_XUqd-RLjlrwDuZHZsGlkSQoLo-qgNkji': {'allele_ids': ['VMC:GA_FDez5GA0kZdSJ--h3stLv9LF8l4OQ-_I',
#     'VMC:GA_8GXRvwUiPqedmbLe8XC5bjU0MAtGzVaf'],
#    'completeness': 'UNKNOWN',
#    'id': 'VMC:GH_XUqd-RLjlrwDuZHZsGlkSQoLo-qgNkji',
#    'location_id': 'VMC:GL_1my1_jue4nJslOX2YrXX12CsFIpFzanZ'},
#   'VMC:GH_URkWr6JSsokL-Gby8Fkq2rtrK3nNAouP': {'allele_ids': ['VMC:GA_FDez5GA0kZdSJ--h3stLv9LF8l4OQ-_I',
#     'VMC:GA_FF1sjhCulonKevwWyUtHz0elzKkMGOia'],
#    'completeness': 'UNKNOWN',
#    'id': 'VMC:GH_URkWr6JSsokL-Gby8Fkq2rtrK3nNAouP',
#    'location_id': 'VMC:GL_1my1_jue4nJslOX2YrXX12CsFIpFzanZ'},
#   'VMC:GH_26h_I4JJ2H-Qf-OftmSCt_y1cyTLm644': {'allele_ids': ['VMC:GA_O67oha84SsAJeSHMHr7aY2R57et-UZUS',
#     'VMC:GA_nDecjk95OUW67OEl8gF5GSdFhMTbCQLR'],
#    'completeness': 'UNKNOWN',
#    'id': 'VMC:GH_26h_I4JJ2H-Qf-OftmSCt_y1cyTLm644',
#    'location_id': 'VMC:GL_8EQXh5U6MxdBxDghe8Z-JSEYefZfmEWq'},
#   'VMC:GH_hQ6S0QXykw_VB_klyfaB91abJfdu5xmE': {'allele_ids': ['VMC:GA_5PpUoSppTEXHTXguTPcQLj7dQrlyuU06',
#     'VMC:GA_nDecjk95OUW67OEl8gF5GSdFhMTbCQLR'],
#    'completeness': 'UNKNOWN',
#    'id': 'VMC:GH_hQ6S0QXykw_VB_klyfaB91abJfdu5xmE',
#    'location_id': 'VMC:GL_8EQXh5U6MxdBxDghe8Z-JSEYefZfmEWq'},
#   'VMC:GH_H4GaT_yDDvJT1SkK5NtsEVfBHJspIncO': {'allele_ids': ['VMC:GA_5PpUoSppTEXHTXguTPcQLj7dQrlyuU06',
#     'VMC:GA_HXfVz-_qMdKeEuF8-jw6JYrjR2aFWC9d'],
#    'completeness': 'UNKNOWN',
#    'id': 'VMC:GH_H4GaT_yDDvJT1SkK5NtsEVfBHJspIncO',
#    'location_id': 'VMC:GL_8EQXh5U6MxdBxDghe8Z-JSEYefZfmEWq'},
#   'VMC:GH_K3iMP1SeScExjniYSpN6-42gowOPwgcu': {'allele_ids': ['VMC:GA_O67oha84SsAJeSHMHr7aY2R57et-UZUS',
#     'VMC:GA_HXfVz-_qMdKeEuF8-jw6JYrjR2aFWC9d'],
#    'completeness': 'UNKNOWN',
#    'id': 'VMC:GH_K3iMP1SeScExjniYSpN6-42gowOPwgcu',
#    'location_id': 'VMC:GL_8EQXh5U6MxdBxDghe8Z-JSEYefZfmEWq'}},
#  'identifiers': {'VMC:GS_ItRDD47aMoioDCNW_occY5fWKZBKlxCX': ['NC_000019.9'],
#   'VMC:GS_IIB53T8CNeJJdUqzn9V_JnRtQadwWCbl': ['NC_000019.10'],
#   'VMC:GS_RARDhX0ZLluRb9MPWPP0UxWuba-L4RiN': ['NM_000041.3'],
#   'VMC:GS_r-ftx4dlYb1eamfOc0Xk9eSFdYxso5Wk': ['NP_000032.1']},
#  'locations': {'VMC:GL_pP3VNZk9XnBbKCpbmWZ_4uo7glzy52B8': {'id': 'VMC:GL_pP3VNZk9XnBbKCpbmWZ_4uo7glzy52B8',
#    'interval': {'end': 45412079, 'start': 45412078},
#    'sequence_id': 'VMC:GS_ItRDD47aMoioDCNW_occY5fWKZBKlxCX'},
#   'VMC:GL_heG_PQopyF0Vgi4zH6yiLf3diyfyJcV3': {'id': 'VMC:GL_heG_PQopyF0Vgi4zH6yiLf3diyfyJcV3',
#    'interval': {'end': 44908822, 'start': 44908821},
#    'sequence_id': 'VMC:GS_IIB53T8CNeJJdUqzn9V_JnRtQadwWCbl'},
#   'VMC:GL_YxX7xmdBNfU4PsUR-SGVbx2UpFplLOfO': {'id': 'VMC:GL_YxX7xmdBNfU4PsUR-SGVbx2UpFplLOfO',
#    'interval': {'end': 526, 'start': 525},
#    'sequence_id': 'VMC:GS_RARDhX0ZLluRb9MPWPP0UxWuba-L4RiN'},
#   'VMC:GL_dTK1c6jdZmkSUqVYQBESKi8-G3U1SvAR': {'id': 'VMC:GL_dTK1c6jdZmkSUqVYQBESKi8-G3U1SvAR',
#    'interval': {'end': 176, 'start': 175},
#    'sequence_id': 'VMC:GS_r-ftx4dlYb1eamfOc0Xk9eSFdYxso5Wk'},
#   'VMC:GL_vCYRMzR95jmQ1VYwpUfthSZ8TVQMFwLB': {'id': 'VMC:GL_vCYRMzR95jmQ1VYwpUfthSZ8TVQMFwLB',
#    'interval': {'end': 45411941, 'start': 45411940},
#    'sequence_id': 'VMC:GS_ItRDD47aMoioDCNW_occY5fWKZBKlxCX'},
#   'VMC:GL_L1IS6jOwSUsOpKihGRcqxHul1IwbV-1s': {'id': 'VMC:GL_L1IS6jOwSUsOpKihGRcqxHul1IwbV-1s',
#    'interval': {'end': 44908684, 'start': 44908683},
#    'sequence_id': 'VMC:GS_IIB53T8CNeJJdUqzn9V_JnRtQadwWCbl'},
#   'VMC:GL_8-ViSIvP5iAmlIt4bXVLOLrA_Nf_emgJ': {'id': 'VMC:GL_8-ViSIvP5iAmlIt4bXVLOLrA_Nf_emgJ',
#    'interval': {'end': 388, 'start': 387},
#    'sequence_id': 'VMC:GS_RARDhX0ZLluRb9MPWPP0UxWuba-L4RiN'},
#   'VMC:GL_TyoxavrWtcusjpiKFmWxVCXSAu98-G6a': {'id': 'VMC:GL_TyoxavrWtcusjpiKFmWxVCXSAu98-G6a',
#    'interval': {'end': 130, 'start': 129},
#    'sequence_id': 'VMC:GS_r-ftx4dlYb1eamfOc0Xk9eSFdYxso5Wk'},
#   'VMC:GL_2VyJB7nPtJwowLsnt4g9glSXXI2dmHS6': {'id': 'VMC:GL_2VyJB7nPtJwowLsnt4g9glSXXI2dmHS6',
#    'interval': {'end': 45412079, 'start': 45411940},
#    'sequence_id': 'VMC:GS_ItRDD47aMoioDCNW_occY5fWKZBKlxCX'},
#   'VMC:GL_8Vq74MSEdcvgKy4XwQWoA8nQAtW-lWV0': {'id': 'VMC:GL_8Vq74MSEdcvgKy4XwQWoA8nQAtW-lWV0',
#    'interval': {'end': 44908822, 'start': 44908683},
#    'sequence_id': 'VMC:GS_IIB53T8CNeJJdUqzn9V_JnRtQadwWCbl'},
#   'VMC:GL_1my1_jue4nJslOX2YrXX12CsFIpFzanZ': {'id': 'VMC:GL_1my1_jue4nJslOX2YrXX12CsFIpFzanZ',
#    'interval': {'end': 526, 'start': 387},
#    'sequence_id': 'VMC:GS_RARDhX0ZLluRb9MPWPP0UxWuba-L4RiN'},
#   'VMC:GL_8EQXh5U6MxdBxDghe8Z-JSEYefZfmEWq': {'id': 'VMC:GL_8EQXh5U6MxdBxDghe8Z-JSEYefZfmEWq',
#    'interval': {'end': 176, 'start': 129},
#    'sequence_id': 'VMC:GS_r-ftx4dlYb1eamfOc0Xk9eSFdYxso5Wk'}},
#  'meta': {'vmc_version': 0, 'generated_at': '2018-10-21T21:15:14.697161'}}

# %%
bm.as_hgvs()
# Out:
# {'alleles': ['NC_000019.9:g.45412079=',
#   'NC_000019.10:g.44908822=',
#   'NM_000041.3:g.526=',
#   'NP_000032.1:g.176=',
#   'NC_000019.9:g.45412079C>T',
#   'NC_000019.10:g.44908822C>T',
#   'NM_000041.3:g.526G>T',
#   'NP_000032.1:g.176R>C',
#   'NC_000019.9:g.45411941=',
#   'NC_000019.10:g.44908684=',
#   'NM_000041.3:g.388=',
#   'NP_000032.1:g.130=',
#   'NC_000019.9:g.45411941T>C',
#   'NC_000019.10:g.44908684T>C',
#   'NP_000032.1:g.130C>R'],
#  'haplotypes': [['NC_000019.9:g.45411941T>C', 'NC_000019.9:g.45412079C>T'],
#   ['NC_000019.9:g.45411941=', 'NC_000019.9:g.45412079C>T'],
#   ['NC_000019.9:g.45411941=', 'NC_000019.9:g.45412079='],
#   ['NC_000019.9:g.45411941T>C', 'NC_000019.9:g.45412079='],
#   ['NC_000019.10:g.44908684T>C', 'NC_000019.10:g.44908822C>T'],
#   ['NC_000019.10:g.44908684=', 'NC_000019.10:g.44908822C>T'],
#   ['NC_000019.10:g.44908684=', 'NC_000019.10:g.44908822='],
#   ['NC_000019.10:g.44908684T>C', 'NC_000019.10:g.44908822='],
#   ['NM_000041.3:g.388=', 'NM_000041.3:g.526G>T'],
#   ['NM_000041.3:g.388=', 'NM_000041.3:g.526='],
#   ['NP_000032.1:g.130C>R', 'NP_000032.1:g.176R>C'],
#   ['NP_000032.1:g.130=', 'NP_000032.1:g.176R>C'],
#   ['NP_000032.1:g.130=', 'NP_000032.1:g.176='],
#   ['NP_000032.1:g.130C>R', 'NP_000032.1:g.176=']],
#  'genotypes': [[['NC_000019.9:g.45411941=', 'NC_000019.9:g.45412079='],
#    ['NC_000019.9:g.45411941=', 'NC_000019.9:g.45412079=']],
#   [['NC_000019.9:g.45411941T>C', 'NC_000019.9:g.45412079='],
#    ['NC_000019.9:g.45411941=', 'NC_000019.9:g.45412079=']],
#   [['NC_000019.9:g.45411941T>C', 'NC_000019.9:g.45412079='],
#    ['NC_000019.9:g.45411941T>C', 'NC_000019.9:g.45412079=']],
#   [['NC_000019.10:g.44908684=', 'NC_000019.10:g.44908822='],
#    ['NC_000019.10:g.44908684=', 'NC_000019.10:g.44908822=']],
#   [['NC_000019.10:g.44908684T>C', 'NC_000019.10:g.44908822='],
#    ['NC_000019.10:g.44908684=', 'NC_000019.10:g.44908822=']],
#   [['NC_000019.10:g.44908684T>C', 'NC_000019.10:g.44908822='],
#    ['NC_000019.10:g.44908684T>C', 'NC_000019.10:g.44908822=']],
#   [['NM_000041.3:g.388=', 'NM_000041.3:g.526='],
#    ['NM_000041.3:g.388=', 'NM_000041.3:g.526=']],
#   [['NP_000032.1:g.130=', 'NP_000032.1:g.176='],
#    ['NP_000032.1:g.130=', 'NP_000032.1:g.176=']],
#   [['NP_000032.1:g.130C>R', 'NP_000032.1:g.176='],
#    ['NP_000032.1:g.130=', 'NP_000032.1:g.176=']],
#   [['NP_000032.1:g.130C>R', 'NP_000032.1:g.176='],
#    ['NP_000032.1:g.130C>R', 'NP_000032.1:g.176=']]]}
